# %%
#importing the library 
import numpy as np
import pandas as pd

#Saving the contents of the dataset file into 'df'

df = pd.read_csv('CVD_cleaned.csv')
#displaying
df.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No         No       No       Yes  Female        70-74
# 1           No         No      Yes        No  Female        70-74
# 2           No         No      Yes        No  Female        60-64
# 3           No         No      Yes        No    Male        75-79
# 4           No         No       No        No    Male          80+
#
#    Height_(cm)  Weight_(kg)    BMI Smoking_History  Alcohol_Consumption  \
# ...

# %%
#identyfying types of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308854 entries, 0 to 308853
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   General_Health                308854 non-null  object
#  1   Checkup                       308854 non-null  object
#  2   Exercise                      308854 non-null  object
#  3   Heart_Disease                 308854 non-null  object
#  4   Skin_Cancer                   308854 non-null  object
#  5   Other_Cancer                  308854 non-null  object
#  6   Depression                    308854 non-null  object
#  7   Diabetes                      308854 non-null  object
#  8   Arthritis                     308854 non-null  object
#  9   Sex                           308854 non-null  object
#  10  Age_Category                  308854 non-null  object
#  11  Height_(cm)                   308854 non-null  float64
# ...

# %%
#understanding the data
df.describe()
# Out:
#          Height_(cm)    Weight_(kg)            BMI  Alcohol_Consumption  \
# count  308854.000000  308854.000000  308854.000000        308854.000000
# mean      170.615249      83.588655      28.626211             5.096366
# std        10.658026      21.343210       6.522323             8.199763
# min        91.000000      24.950000      12.020000             0.000000
# 25%       163.000000      68.040000      24.210000             0.000000
# 50%       170.000000      81.650000      27.440000             1.000000
# 75%       178.000000      95.250000      31.850000             6.000000
# max       241.000000     293.020000      99.330000            30.000000
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# count      308854.000000                 308854.000000
# mean           29.835200                     15.110441
# std            24.875735                     14.926238
# min             0.000000                      0.000000
# ...

# %%
#Data Visualization(Understanding the types of variables)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#checking relationships among varaibles in pairplot
sns.pairplot(df)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.General_Health.value_counts()
# Out:
# General_Health
# Very Good    110395
# Good          95364
# Excellent     55954
# Fair          35810
# Poor          11331
# Name: count, dtype: int64

# %%
df.Checkup.value_counts()
# Out:
# Checkup
# Within the past year       239371
# Within the past 2 years     37213
# Within the past 5 years     17442
# 5 or more years ago         13421
# Never                        1407
# Name: count, dtype: int64

# %%
df.Exercise.value_counts()
# Out:
# Exercise
# Yes    239381
# No      69473
# Name: count, dtype: int64

# %%
df.Heart_Disease.value_counts()
# Out:
# Heart_Disease
# No     283883
# Yes     24971
# Name: count, dtype: int64

# %%
df.Skin_Cancer.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 308849    No
# 308850    No
# 308851    No
# 308852    No
# 308853    No
# Name: Skin_Cancer, Length: 308854, dtype: object>

# %%
df.Other_Cancer.value_counts()
# Out:
# Other_Cancer
# No     278976
# Yes     29878
# Name: count, dtype: int64

# %%
df.Depression.value_counts()
# Out:
# Depression
# No     246953
# Yes     61901
# Name: count, dtype: int64

# %%
df.Diabetes.value_counts()
# Out:
# Diabetes
# No                                            259141
# Yes                                            40171
# No, pre-diabetes or borderline diabetes         6896
# Yes, but female told only during pregnancy      2646
# Name: count, dtype: int64

# %%
df.Arthritis.value_counts()
# Out:
# Arthritis
# No     207783
# Yes    101071
# Name: count, dtype: int64

# %%
df.Sex.value_counts()
# Out:
# Sex
# Female    160196
# Male      148658
# Name: count, dtype: int64

# %%
df.Age_Category.value_counts()
# Out:
# Age_Category
# 65-69    33434
# 60-64    32418
# 70-74    31103
# 55-59    28054
# 50-54    25097
# 80+      22271
# 40-44    21595
# 45-49    20968
# 75-79    20705
# 35-39    20606
# 18-24    18681
# 30-34    18428
# 25-29    15494
# Name: count, dtype: int64

# %%
df = df.rename(columns={'Height_(cm)':'Height', 'Weight_(kg)': 'Weight'})

# %%
df.Height.value_counts()
# Out:
# Height
# 168.0    27119
# 163.0    25804
# 170.0    24739
# 178.0    24673
# 173.0    23591
#          ...
# 110.0        1
# 241.0        1
# 115.0        1
# 195.0        1
# 108.0        1
# Name: count, Length: 99, dtype: int64

# %%
df.Weight.value_counts()
# Out:
# Weight
# 90.72     16614
# 81.65     15104
# 72.57     13263
# 68.04     13240
# 77.11     12216
#           ...
# 273.52        1
# 176.00        1
# 212.73        1
# 190.96        1
# 42.00         1
# Name: count, Length: 525, dtype: int64

# %%
df.BMI.value_counts()
# Out:
# BMI
# 26.63    3340
# 27.46    2658
# 24.41    2596
# 27.44    2567
# 27.12    2259
#          ...
# 63.92       1
# 50.59       1
# 58.63       1
# 75.37       1
# 56.32       1
# Name: count, Length: 3654, dtype: int64

# %%
df.Smoking_History.value_counts()
# Out:
# Smoking_History
# No     183590
# Yes    125264
# Name: count, dtype: int64

# %%
df.Alcohol_Consumption.value_counts()
# Out:
# Alcohol_Consumption
# 0.0     140262
# 1.0      24983
# 4.0      23367
# 2.0      19740
# 8.0      13438
# 30.0     11976
# 3.0      11479
# 5.0       9622
# 20.0      9372
# 12.0      8825
# 10.0      7881
# 15.0      6178
# 28.0      5935
# 16.0      3602
# 6.0       3518
# 25.0      2670
# 7.0       2572
# 24.0      1253
# 14.0       486
# 29.0       309
# 9.0        239
# 27.0       205
# 21.0       197
# 18.0       196
# 22.0       152
# 26.0       126
# 17.0        78
# 13.0        76
# 23.0        65
# 11.0        41
# 19.0        11
# Name: count, dtype: int64

# %%
df.Green_Vegetables_Consumption.value_counts()
# Out:
# Green_Vegetables_Consumption
# 30.0     51162
# 12.0     41979
# 8.0      40329
# 4.0      37709
# 16.0     23338
#          ...
# 34.0         1
# 93.0         1
# 128.0        1
# 37.0         1
# 53.0         1
# Name: count, Length: 75, dtype: int64

# %%
df.FriedPotato_Consumption.value_counts()
# Out:
# FriedPotato_Consumption
# 4.0     67833
# 0.0     44233
# 8.0     38366
# 2.0     36095
# 1.0     29876
#         ...
# 49.0        1
# 76.0        1
# 34.0        1
# 98.0        1
# 97.0        1
# Name: count, Length: 69, dtype: int64

# %%
df.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  Height  \
# 0           No         No       No       Yes  Female        70-74   150.0
# 1           No         No      Yes        No  Female        70-74   165.0
# 2           No         No      Yes        No  Female        60-64   163.0
# 3           No         No      Yes        No    Male        75-79   180.0
# 4           No         No       No        No    Male          80+   191.0
#
# ...

# %%
General_dummy = pd.get_dummies(df.General_Health, prefix = 'Health', drop_first = True)
General_dummy.head()
# Out:
#    Health_Fair  Health_Good  Health_Poor  Health_Very Good
# 0        False        False         True             False
# 1        False        False        False              True
# 2        False        False        False              True
# 3        False        False         True             False
# 4        False         True        False             False

# %%
Checkup_dummy = pd.get_dummies(df.Checkup,prefix = 'Checkup', drop_first = True)
Checkup_dummy.head()
# Out:
#    Checkup_Never  Checkup_Within the past 2 years  \
# 0          False                             True
# 1          False                            False
# 2          False                            False
# 3          False                            False
# 4          False                            False
#
#    Checkup_Within the past 5 years  Checkup_Within the past year
# 0                            False                         False
# 1                            False                          True
# 2                            False                          True
# 3                            False                          True
# 4                            False                          True

# %%
Exercise_dummy = pd.get_dummies(df.Exercise,prefix = 'Exercise', drop_first = True)
Exercise_dummy.head()
# Out:
#    Exercise_Yes
# 0         False
# 1         False
# 2          True
# 3          True
# 4         False

# %%
Heart_Disease_dummy = pd.get_dummies(df.Heart_Disease, prefix = 'Heart_D', drop_first = True)
Heart_Disease_dummy.head()
# Out:
#    Heart_D_Yes
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False

# %%
Skin_Cancer_dummy = pd.get_dummies(df.Skin_Cancer,prefix = 'Skin_C', drop_first = True)
Skin_Cancer_dummy.head()
# Out:
#    Skin_C_Yes
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
Other_Cancer_dummy = pd.get_dummies(df.Other_Cancer,prefix = 'Other_C', drop_first = True)
Other_Cancer_dummy.head()
# Out:
#    Other_C_Yes
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
Depression_dummy = pd.get_dummies(df.Depression,prefix = 'Depression', drop_first = True)
Depression_dummy.head()
# Out:
#    Depression_Yes
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False

# %%
df.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  Height  \
# 0           No         No       No       Yes  Female        70-74   150.0
# 1           No         No      Yes        No  Female        70-74   165.0
# 2           No         No      Yes        No  Female        60-64   163.0
# 3           No         No      Yes        No    Male        75-79   180.0
# 4           No         No       No        No    Male          80+   191.0
#
# ...

# %%
Diabetes_dummy = pd.get_dummies(df.Diabetes, prefix = 'Diabetes', drop_first = True)
Diabetes_dummy.head()
# Out:
#    Diabetes_No, pre-diabetes or borderline diabetes  Diabetes_Yes  \
# 0                                             False         False
# 1                                             False          True
# 2                                             False          True
# 3                                             False          True
# 4                                             False         False
#
#    Diabetes_Yes, but female told only during pregnancy
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False

# %%
Diabetes_dummy = Diabetes_dummy.rename(columns = {'Diabetes_No, pre-diabetes or borderline diabetes': '!Diabetes_pre_bor', 'Diabetes_Yes, but female told only during pregnancy': 'Diabetes_Yes_Pregnancy'})
Diabetes_dummy.head()
# Out:
#    !Diabetes_pre_bor  Diabetes_Yes  Diabetes_Yes_Pregnancy
# 0              False         False                   False
# 1              False          True                   False
# 2              False          True                   False
# 3              False          True                   False
# 4              False         False                   False

# %%
Arthritis_dummy = pd.get_dummies(df.Arthritis,prefix = 'Arthititis', drop_first = True)
Arthritis_dummy.head()
# Out:
#    Arthititis_Yes
# 0            True
# 1           False
# 2           False
# 3           False
# 4           False

# %%
Sex_dummy = pd.get_dummies(df.Sex,prefix = 'Sex', drop_first = True)
Sex_dummy.head()
# Out:
#    Sex_Male
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True

# %%
Age_dummy = pd.get_dummies(df.Age_Category,prefix = 'Age', drop_first = True)
Age_dummy.head()
# Out:
#    Age_25-29  Age_30-34  Age_35-39  Age_40-44  Age_45-49  Age_50-54  \
# 0      False      False      False      False      False      False
# 1      False      False      False      False      False      False
# 2      False      False      False      False      False      False
# 3      False      False      False      False      False      False
# 4      False      False      False      False      False      False
#
#    Age_55-59  Age_60-64  Age_65-69  Age_70-74  Age_75-79  Age_80+
# 0      False      False      False       True      False    False
# 1      False      False      False       True      False    False
# 2      False       True      False      False      False    False
# 3      False      False      False      False       True    False
# 4      False      False      False      False      False     True

# %%
df.Age_Category.value_counts()
# Out:
# Age_Category
# 65-69    33434
# 60-64    32418
# 70-74    31103
# 55-59    28054
# 50-54    25097
# 80+      22271
# 40-44    21595
# 45-49    20968
# 75-79    20705
# 35-39    20606
# 18-24    18681
# 30-34    18428
# 25-29    15494
# Name: count, dtype: int64

# %%
Smoking_dummy = pd.get_dummies(df.Smoking_History, prefix ='Smoking', drop_first = True)
Smoking_dummy.head()
# Out:
#    Smoking_Yes
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True

# %%
df.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  Height  \
# 0           No         No       No       Yes  Female        70-74   150.0
# 1           No         No      Yes        No  Female        70-74   165.0
# 2           No         No      Yes        No  Female        60-64   163.0
# 3           No         No      Yes        No    Male        75-79   180.0
# 4           No         No       No        No    Male          80+   191.0
#
# ...

# %%
final = pd.concat([df,General_dummy,Checkup_dummy, Exercise_dummy, Heart_Disease_dummy, Skin_Cancer_dummy, Other_Cancer_dummy, Depression_dummy, Diabetes_dummy, Arthritis_dummy, Sex_dummy, Age_dummy, Smoking_dummy], axis = 1)
final.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex  ... Age_40-44  \
# 0           No         No       No       Yes  Female  ...     False
# 1           No         No      Yes        No  Female  ...     False
# 2           No         No      Yes        No  Female  ...     False
# 3           No         No      Yes        No    Male  ...     False
# 4           No         No       No        No    Male  ...     False
#
#    Age_45-49  Age_50-54  Age_55-59 Age_60-64  Age_65-69  Age_70-74  Age_75-79  \
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308854 entries, 0 to 308853
# Data columns (total 50 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   General_Health                   308854 non-null  object
#  1   Checkup                          308854 non-null  object
#  2   Exercise                         308854 non-null  object
#  3   Heart_Disease                    308854 non-null  object
#  4   Skin_Cancer                      308854 non-null  object
#  5   Other_Cancer                     308854 non-null  object
#  6   Depression                       308854 non-null  object
#  7   Diabetes                         308854 non-null  object
#  8   Arthritis                        308854 non-null  object
#  9   Sex                              308854 non-null  object
#  10  Age_Category                     308854 non-null  object
# ...

# %%
final
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 0                Poor  Within the past 2 years       No            No
# 1           Very Good     Within the past year       No           Yes
# 2           Very Good     Within the past year      Yes            No
# 3                Poor     Within the past year      Yes           Yes
# 4                Good     Within the past year       No            No
# ...               ...                      ...      ...           ...
# 308849      Very Good     Within the past year      Yes            No
# 308850           Fair  Within the past 5 years      Yes            No
# 308851      Very Good      5 or more years ago      Yes            No
# 308852      Very Good     Within the past year      Yes            No
# 308853      Excellent     Within the past year      Yes            No
#
#        Skin_Cancer Other_Cancer Depression  \
# 0               No           No         No
# ...

# %%
final = final.drop(['General_Health', 'Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer', 'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex','Age_Category','Smoking_History'], axis = 1)

# %%
final.head()
# Out:
#    Height  Weight    BMI  Alcohol_Consumption  Fruit_Consumption  \
# 0   150.0   32.66  14.54                  0.0               30.0
# 1   165.0   77.11  28.29                  0.0               30.0
# 2   163.0   88.45  33.47                  4.0               12.0
# 3   180.0   93.44  28.73                  0.0               30.0
# 4   191.0   88.45  24.37                  0.0                8.0
#
#    Green_Vegetables_Consumption  FriedPotato_Consumption  Health_Fair  \
# 0                          16.0                     12.0        False
# 1                           0.0                      4.0        False
# 2                           3.0                     16.0        False
# 3                          30.0                      8.0        False
# 4                           4.0                      0.0        False
#
#    Health_Good  Health_Poor  ...  Age_40-44  Age_45-49  Age_50-54  Age_55-59  \
# ...

# %%
#dividing the data into train and test set
import sklearn
from sklearn.model_selection import train_test_split

# %%
# dividing the data into train and test split

final_train, final_test = train_test_split(final, train_size = 0.8, random_state = 100)
print(final_train.shape)
print(final_test.shape)
# Out:
# (247083, 38)
# (61771, 38)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
#Instiating scaler object 

scaler = MinMaxScaler()

# %%
# creating a list of numeric variables 

numeric = ['Height','Weight','Alcohol_Consumption', 'Fruit_Consumption', 'Green_Vegetables_Consumption', 'FriedPotato_Consumption','BMI']

# %%
# fitting the scaler on the dataframe 

final_train[numeric] = scaler.fit_transform(final_train[numeric])

# %%
final_train.head()
# Out:
#           Height    Weight       BMI  Alcohol_Consumption  Fruit_Consumption  \
# 103515  0.546667  0.245346  0.211015             0.066667           0.166667
# 214513  0.513333  0.104898  0.078715             0.133333           0.050000
# 246942  0.440000  0.115045  0.120252             0.066667           0.250000
# 300405  0.513333  0.162420  0.141710             0.000000           0.041667
# 167957  0.580000  0.238557  0.184739             0.833333           0.066667
#
#         Green_Vegetables_Consumption  FriedPotato_Consumption  Health_Fair  \
# 103515                      0.156250                 0.078125        False
# 214513                      0.023438                 0.031250        False
# 246942                      0.093750                 0.031250        False
# 300405                      0.007812                 0.000000        False
# 167957                      0.039062                 0.031250        False
#
# ...

# %%
final_train.describe()
# Out:
#               Height         Weight            BMI  Alcohol_Consumption  \
# count  247083.000000  247083.000000  247083.000000        247083.000000
# mean        0.530934       0.218769       0.190489             0.170126
# std         0.071083       0.079618       0.074847             0.273541
# min         0.000000       0.000000       0.000000             0.000000
# 25%         0.480000       0.160742       0.139874             0.000000
# 50%         0.526667       0.211512       0.176936             0.033333
# 75%         0.580000       0.262245       0.227309             0.200000
# max         1.000000       1.000000       1.000000             1.000000
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# count      247083.000000                 247083.000000
# mean            0.248728                      0.117960
# std             0.207452                      0.116477
# min             0.000000                      0.000000
# ...

# %%
y_train = final_train.pop('BMI')
x_train = final_train

# %%
# observing y_train
y_train.head()
# Out:
# 103515    0.211015
# 214513    0.078715
# 246942    0.120252
# 300405    0.141710
# 167957    0.184739
# Name: BMI, dtype: float64

# %%
# observing x_train
x_train.head()
# Out:
#           Height    Weight  Alcohol_Consumption  Fruit_Consumption  \
# 103515  0.546667  0.245346             0.066667           0.166667
# 214513  0.513333  0.104898             0.133333           0.050000
# 246942  0.440000  0.115045             0.066667           0.250000
# 300405  0.513333  0.162420             0.000000           0.041667
# 167957  0.580000  0.238557             0.833333           0.066667
#
#         Green_Vegetables_Consumption  FriedPotato_Consumption  Health_Fair  \
# 103515                      0.156250                 0.078125        False
# 214513                      0.023438                 0.031250        False
# 246942                      0.093750                 0.031250        False
# 300405                      0.007812                 0.000000        False
# 167957                      0.039062                 0.031250        False
#
#         Health_Good  Health_Poor  Health_Very Good  ...  Age_40-44  Age_45-49  \
# ...

# %%
#Data Modeling
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# adding constant as statsmodel.api doesnot include constants

x_train_sm = sm.add_constant(x_train)

# creating the model based on Ordinary Least Squares 

lr = sm.OLS(y_train,x_train_sm)

# fitting the straight line that best fits to our dataset 

lr_model = lr.fit()

#printing the summary of the model

lr_model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 7
#       3 x_train_sm = sm.add_constant(x_train)
#       5 # creating the model based on Ordinary Least Squares
# ----> 7 lr = sm.OLS(y_train,x_train_sm)
#       9 # fitting the straight line that best fits to our dataset
#      11 lr_model = lr.fit()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:922, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     919     msg = ("Weights are not supported in OLS and will be ignored"
#     920            "An exception will be raised in the next version.")
#     921     warnings.warn(msg, ValueWarning)
# --> 922 super(OLS, self).__init__(endog, exog, missing=missing,
#     923                           hasconst=hasconst, **kwargs)
#     924 if "weights" in self._init_keys:
# ...

# %%
# creating a new dataframe that consists of the name of the variables and their respective VIF

vif = pd.DataFrame()

# assigning the column 'variables' with the columns of X_train 

vif['variables'] = x_train.columns

# assigning the column 'VIF' with the VIF values of the variales 

vif['VIF'] = [variance_inflation_factor(x_train.values,i) for i in range (x_train.shape[1])]

# rounding off the VIF values to 2 decimal places 

vif['VIF'] = round(vif['VIF'],2)

# sorting the VIF values in descending order 

vif = vif.sort_values(by = 'VIF' , ascending = False)

# printing the dataframe vif 

vif
# Out:
#                           variables    VIF
# 0                            Height  50.62
# 13     Checkup_Within the past year  16.66
# 1                            Weight  12.77
# 14                     Exercise_Yes   5.04
# 11  Checkup_Within the past 2 years   3.33
# 23                         Sex_Male   3.20
# 9                  Health_Very Good   2.99
# 7                       Health_Good   2.92
# 32                        Age_65-69   2.87
# 33                        Age_70-74   2.80
# 31                        Age_60-64   2.75
# 3                 Fruit_Consumption   2.72
# 30                        Age_55-59   2.47
# 35                          Age_80+   2.36
# 29                        Age_50-54   2.29
# 34                        Age_75-79   2.25
# 4      Green_Vegetables_Consumption   2.25
# 27                        Age_40-44   2.09
# 12  Checkup_Within the past 5 years   2.08
# 28                        Age_45-49   2.06
# 26                        Age_35-39   2.01
# ...

# %%
#removing Health_Good because of very low significance

x_train = x_train.drop('Health_Good', axis =1)

# %%
x_train_sm = sm.add_constant(x)

lr = sm.OLS(y_train,x_train_sm)

lr_model = lr.fit()

lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    BMI   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 3.492e+05
# Date:                Sat, 22 Jul 2023   Prob (F-statistic):               0.00
# Time:                        14:16:16   Log-Likelihood:             7.7778e+05
# No. Observations:              247083   AIC:                        -1.555e+06
# Df Residuals:                  247046   BIC:                        -1.555e+06
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
# creating a new dataframe that consists of the name of the variables and their respective VIF

vif = pd.DataFrame()

# assigning the column 'variables' with the columns of X_train 

vif['variables'] = x_train.columns

# assigning the column 'VIF' with the VIF values of the variales 

vif['VIF'] = [variance_inflation_factor(x_train.values,i) for i in range (x_train.shape[1])]

# rounding off the VIF values to 2 decimal places 

vif['VIF'] = round(vif['VIF'],2)

# sorting the VIF values in descending order 

vif = vif.sort_values(by = 'VIF' , ascending = False)

# printing the dataframe vif 

vif
# Out:
#                           variables    VIF
# 0                            Height  49.99
# 12     Checkup_Within the past year  16.51
# 1                            Weight  12.55
# 13                     Exercise_Yes   5.03
# 10  Checkup_Within the past 2 years   3.30
# 22                         Sex_Male   3.18
# 31                        Age_65-69   2.86
# 32                        Age_70-74   2.79
# 30                        Age_60-64   2.74
# 3                 Fruit_Consumption   2.72
# 29                        Age_55-59   2.47
# 34                          Age_80+   2.34
# 28                        Age_50-54   2.28
# 33                        Age_75-79   2.24
# 4      Green_Vegetables_Consumption   2.24
# 26                        Age_40-44   2.09
# 11  Checkup_Within the past 5 years   2.07
# 27                        Age_45-49   2.06
# 25                        Age_35-39   2.01
# 21                   Arthititis_Yes   1.88
# 24                        Age_30-34   1.88
# ...

# %%
x_train.head()
# Out:
#           Height    Weight  Alcohol_Consumption  Fruit_Consumption  \
# 103515  0.546667  0.245346             0.066667           0.166667
# 214513  0.513333  0.104898             0.133333           0.050000
# 246942  0.440000  0.115045             0.066667           0.250000
# 300405  0.513333  0.162420             0.000000           0.041667
# 167957  0.580000  0.238557             0.833333           0.066667
#
#         Green_Vegetables_Consumption  FriedPotato_Consumption  Health_Fair  \
# 103515                      0.156250                 0.078125        False
# 214513                      0.023438                 0.031250        False
# 246942                      0.093750                 0.031250        False
# 300405                      0.007812                 0.000000        False
# 167957                      0.039062                 0.031250        False
#
#         Health_Good  Health_Poor  Health_Very Good  ...  Age_40-44  Age_45-49  \
# ...

# %%
x = x_train.drop('Checkup_Within the past 5 years', axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 x = x_train.drop('Checkup_Within the past 5 years', axis =1)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
x_train_sm = sm.add_constant(x)

lr = sm.OLS(y_train,x_train_sm)

lr_model = lr.fit()

lr_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 x_train_sm = sm.add_constant(x)
#       3 lr = sm.OLS(y_train,x_train_sm)
#       5 lr_model = lr.fit()
#
# NameError: name 'x' is not defined

# %%
# creating a new dataframe that consists of the name of the variables and their respective VIF

vif = pd.DataFrame()

# assigning the column 'variables' with the columns of X_train 

vif['variables'] = x_train.columns

# assigning the column 'VIF' with the VIF values of the variales 

vif['VIF'] = [variance_inflation_factor(x_train.values,i) for i in range (x_train.shape[1])]

# rounding off the VIF values to 2 decimal places 

vif['VIF'] = round(vif['VIF'],2)

# sorting the VIF values in descending order 

vif = vif.sort_values(by = 'VIF' , ascending = False)

# printing the dataframe vif 

vif
# Out:
#                           variables    VIF
# 0                            Height  41.18
# 1                            Weight  12.54
# 11     Checkup_Within the past year   8.82
# 12                     Exercise_Yes   5.02
# 21                         Sex_Male   3.06
# 30                        Age_65-69   2.85
# 31                        Age_70-74   2.77
# 29                        Age_60-64   2.72
# 3                 Fruit_Consumption   2.72
# 28                        Age_55-59   2.46
# 33                          Age_80+   2.32
# 27                        Age_50-54   2.27
# 4      Green_Vegetables_Consumption   2.24
# 32                        Age_75-79   2.23
# 10  Checkup_Within the past 2 years   2.12
# 25                        Age_40-44   2.08
# 26                        Age_45-49   2.05
# 24                        Age_35-39   2.00
# 20                   Arthititis_Yes   1.88
# 23                        Age_30-34   1.87
# 34                      Smoking_Yes   1.84
# ...
