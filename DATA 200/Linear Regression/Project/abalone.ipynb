# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('abalone.csv')

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
data['weight'] = data['Rings'] + 1.5
data = data.drop(['Rings'],axis=1)
dataa
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  weight
# 0             0.1010        0.1500    16.5
# 1             0.0485        0.0700     8.5
# 2             0.1415        0.2100    10.5
# 3             0.1140        0.1550    11.5
# 4             0.0395        0.0550     8.5
# ...              ...           ...     ...
# 4172          0.2390        0.2490    12.5
# 4173          0.2145        0.2605    11.5
# 4174          0.2875        0.3080    10.5
# 4175          0.2610        0.2960    11.5
# 4176          0.3765        0.4950    13.5
#
# [4177 rows x 9 columns]

# %%
data.shape
# Out:
# (4177, 9)

# %%
data.describe(include='all')
# Out:
#          Sex       Length     Diameter       Height  Whole weight  \
# count   4177  4177.000000  4177.000000  4177.000000   4177.000000
# unique     3          NaN          NaN          NaN           NaN
# top        M          NaN          NaN          NaN           NaN
# freq    1528          NaN          NaN          NaN           NaN
# mean     NaN     0.523992     0.407881     0.139516      0.828742
# std      NaN     0.120093     0.099240     0.041827      0.490389
# min      NaN     0.075000     0.055000     0.000000      0.002000
# 25%      NaN     0.450000     0.350000     0.115000      0.441500
# 50%      NaN     0.545000     0.425000     0.140000      0.799500
# 75%      NaN     0.615000     0.480000     0.165000      1.153000
# max      NaN     0.815000     0.650000     1.130000      2.825500
#
#         Shucked weight  Viscera weight  Shell weight       weight
# count      4177.000000     4177.000000   4177.000000  4177.000000
# unique             NaN             NaN           NaN          NaN
# top                NaN             NaN           NaN          NaN
# freq               NaN             NaN           NaN          NaN
# mean          0.359367        0.180594      0.238831    11.433684
# std           0.221963        0.109614      0.139203     3.224169
# min           0.001000        0.000500      0.001500     2.500000
# 25%           0.186000        0.093500      0.130000     9.500000
# 50%           0.336000        0.171000      0.234000    10.500000
# 75%           0.502000        0.253000      0.329000    12.500000
# max           1.488000        0.760000      1.005000    30.500000

# %%
sns.pairplot(data)
plt.show()

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# weight            0
# dtype: int64

# %%
sns.distplot(data['weight'])
plt.show()

# %%
q = data['weight'].quantile(0.99)
data_1 = data[data['weight']<q]
data_1.describe(include='all')
# Out:
#          Sex       Length     Diameter       Height  Whole weight  \
# count   4115  4115.000000  4115.000000  4115.000000   4115.000000
# unique     3          NaN          NaN          NaN           NaN
# top        M          NaN          NaN          NaN           NaN
# freq    1501          NaN          NaN          NaN           NaN
# mean     NaN     0.522712     0.406738     0.138944      0.821987
# std      NaN     0.120241     0.099266     0.041767      0.488183
# min      NaN     0.075000     0.055000     0.000000      0.002000
# 25%      NaN     0.450000     0.345000     0.115000      0.438500
# 50%      NaN     0.540000     0.425000     0.140000      0.793000
# 75%      NaN     0.615000     0.480000     0.165000      1.145000
# max      NaN     0.815000     0.650000     1.130000      2.825500
#
#         Shucked weight  Viscera weight  Shell weight       weight
# count      4115.000000     4115.000000   4115.000000  4115.000000
# unique             NaN             NaN           NaN          NaN
# top                NaN             NaN           NaN          NaN
# freq               NaN             NaN           NaN          NaN
# mean          0.357979        0.179528      0.235866    11.258931
# std           0.222440        0.109454      0.136871     2.904193
# min           0.001000        0.000500      0.001500     2.500000
# 25%           0.183250        0.092000      0.129000     9.500000
# 50%           0.334000        0.169000      0.230000    10.500000
# 75%           0.500750        0.251500      0.324500    12.500000
# max           1.488000        0.760000      1.005000    20.500000

# %%
data.Sex.value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(), annot = True)
plt.show()
